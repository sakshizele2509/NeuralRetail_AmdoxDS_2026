# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/silver/retail_clean.csv")

df.describe()

sns.histplot(df["TotalPrice"])
plt.show()
# Out:
# Running cells with 'Python 3.9.0' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/dell/AppData/Local/Programs/Python/Python39/python.exe -m pip install ipykernel -U --user --force-reinstall'
